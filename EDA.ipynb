# %% [markdown]
# [Data Source](https://data.kingcounty.gov/Health-Wellness/Food-Establishment-Inspection-Data/f29f-zza5/about_data)
#
# [Rating System](https://kingcounty.gov/en/dept/dph/health-safety/food-safety/inspection-rating-system/rating-system)
#
# [Permit types and risk categories](https://kingcounty.gov/en/dept/dph/health-safety/food-safety/inspection-rating-system/rating-system#:~:text=recorded%20meeting.-,Permit%20types%20and%20risk%20categories,-Who%27s%20included%20in)

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Settings
# %matplotlib inline
sns.set_context("paper", font_scale=1.25)

pd.set_option('display.max_columns', 100)
pd.set_option('display.float_format', lambda x: f'{x:,.2f}')
pd.set_option('display.max_rows', 50)

# %% [markdown]
# # Import Data

# %%
data_path = './data/Food_Establishment_Inspection_Data_20240220.csv'

source = pd.read_csv(data_path, low_memory=False)
source.head()
# Out:
#                Name Program Identifier Inspection Date  \
# 0  #807 TUTTA BELLA   #807 TUTTA BELLA      03/02/2023
# 1  #807 TUTTA BELLA   #807 TUTTA BELLA      03/02/2023
# 2  #807 TUTTA BELLA   #807 TUTTA BELLA      08/31/2022
# 3  #807 TUTTA BELLA   #807 TUTTA BELLA      08/31/2022
# 4  #807 TUTTA BELLA   #807 TUTTA BELLA      01/13/2022
#
#                         Description          Address     City Zip Code  \
# 0  Seating 0-12 - Risk Category III  2746 NE 45TH ST  SEATTLE    98105
# 1  Seating 0-12 - Risk Category III  2746 NE 45TH ST  SEATTLE    98105
# 2  Seating 0-12 - Risk Category III  2746 NE 45TH ST  SEATTLE    98105
# 3  Seating 0-12 - Risk Category III  2746 NE 45TH ST  SEATTLE    98105
# 4  Seating 0-12 - Risk Category III  2746 NE 45TH ST  SEATTLE    98105
#
#             Phone  Longitude  Latitude Inspection Business Name  \
# 0  (206) 722-6400    -122.30     47.66         #807 TUTTA BELLA
# 1  (206) 722-6400    -122.30     47.66         #807 TUTTA BELLA
# 2  (206) 722-6400    -122.30     47.66         #807 TUTTA BELLA
# 3  (206) 722-6400    -122.30     47.66         #807 TUTTA BELLA
# 4  (206) 722-6400    -122.30     47.66         #807 TUTTA BELLA
#
#                    Inspection Type  Inspection Score Inspection Result  \
# 0  Routine Inspection/Field Review             20.00    Unsatisfactory
# 1  Routine Inspection/Field Review             20.00    Unsatisfactory
# 2  Routine Inspection/Field Review             10.00    Unsatisfactory
# 3  Routine Inspection/Field Review             10.00    Unsatisfactory
# 4  Routine Inspection/Field Review              0.00      Satisfactory
#
#   Inspection Closed Business Violation Type  \
# 0                      False            RED
# 1                      False            RED
# 2                      False           BLUE
# 3                      False            RED
# 4                      False            NaN
#
#                                Violation Description  Violation Points  \
# 0  1300 - Food contact surfaces cleaned and sanit...                15
# 1  2120 - Proper cold holding temperatures ( 42 d...                 5
# 2  3200 - Insects, rodents, animals not present; ...                 5
# 3  0200 - Food Worker Cards current for all food ...                 5
# 4                                                NaN                 0
#
#   Business_ID Inspection_Serial_Num Violation_Record_ID  Grade
# 0   PR0089260             DAJ5DTHLV           IVBTPZO0B   1.00
# 1   PR0089260             DAJ5DTHLV           IV5GOME67   1.00
# 2   PR0089260             DAEEWQC0L           IVQ7QYW2V   1.00
# 3   PR0089260             DAEEWQC0L           IV0J437H6   1.00
# 4   PR0089260             DAWWGK08K                 NaN   1.00

# %% [markdown]
# # Review Data Quality

# %%
source.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261681 entries, 0 to 261680
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Name                        261681 non-null  object
#  1   Program Identifier          261681 non-null  object
#  2   Inspection Date             261219 non-null  object
#  3   Description                 261681 non-null  object
#  4   Address                     261681 non-null  object
#  5   City                        261681 non-null  object
#  6   Zip Code                    261681 non-null  object
#  7   Phone                       190250 non-null  object
#  8   Longitude                   260689 non-null  float64
#  9   Latitude                    260689 non-null  float64
#  10  Inspection Business Name    261219 non-null  object
#  11  Inspection Type             261219 non-null  object
#  12  Inspection Score            261182 non-null  float64
#  13  Inspection Result           261219 non-null  object
#  14  Inspection Closed Business  261219 non-null  object
#  15  Violation Type              146373 non-null  object
#  16  Violation Description       146373 non-null  object
#  17  Violation Points            261681 non-null  int64
#  18  Business_ID                 261681 non-null  object
#  19  Inspection_Serial_Num       261219 non-null  object
#  20  Violation_Record_ID         146373 non-null  object
#  21  Grade                       197805 non-null  float64
# dtypes: float64(4), int64(1), object(17)
# memory usage: 43.9+ MB

# %% [markdown]
# ## Inspect Missing Values

# %%
source.isna().sum()
# Out:
# Name                               0
# Program Identifier                 0
# Inspection Date                  462
# Description                        0
# Address                            0
# City                               0
# Zip Code                           0
# Phone                          71431
# Longitude                        992
# Latitude                         992
# Inspection Business Name         462
# Inspection Type                  462
# Inspection Score                 499
# Inspection Result                462
# Inspection Closed Business       462
# Violation Type                115308
# Violation Description         115308
# Violation Points                   0
# Business_ID                        0
# Inspection_Serial_Num            462
# Violation_Record_ID           115308
# Grade                          63876
# dtype: int64

# %%
source[source['Inspection Closed Business'].isna()]
# Out:
#                                  Name  \
# 20                  1 OAK  SANDWICHES
# 175     12S TACOS MEXICAN FOOD KC1012
# 182                    12TH AVE SLICE
# 603      3BROS VIETNAMESE CUISINE LLC
# 674                405 EXPRESS MARKET
# ...                               ...
# 258958                       YAKIMONO
# 258980                        YAN TEA
# 259929            YUMMY ASIAN CUISINE
# 260668    ZAINA FOOD DRINKS & FRIENDS
# 261284                      ZEMA CAFE
#
#                                        Program Identifier Inspection Date  \
# 20      1 OAK  SANDWICHES @ 1314 AUBURN WAY N AUBURN 9...             NaN
# 175                         12S TACOS MEXICAN FOOD KC1012             NaN
# 182                                        12TH AVE SLICE             NaN
# 603                          3BROS VIETNAMESE CUISINE LLC             NaN
# 674                                    405 EXPRESS MARKET             NaN
# ...                                                   ...             ...
# 258958                     YAKIMONO @ ROUTE  425 728 0706             NaN
# 258980                                            YAN TEA             NaN
# 259929                                YUMMY ASIAN CUISINE             NaN
# 260668                        ZAINA FOOD DRINKS & FRIENDS             NaN
# 261284                                          ZEMA CAFE             NaN
#
#                                        Description                  Address  \
# 20            Mobile Food Unit - Risk Category III         5805 LACEY BL SE
# 175           Mobile Food Unit - Risk Category III             625 S 4TH ST
# 182              Seating 13-50 - Risk Category III            1542 12TH AVE
# 603              Seating 13-50 - Risk Category III          14611 1ST AVE S
# 674     Grocery Store-no seating - Risk Category I  1800 NE 44TH ST STE 100
# ...                                            ...                      ...
# 258958        Mobile Food Unit - Risk Category III   10836 E MARGINAL WAY S
# 258980            Seating 0-12 - Risk Category III   4474 University WAY NE
# 259929          Seating 51-150 - Risk Category III     22228 PACIFIC HWY S
# 260668           Seating 13-50 - Risk Category III          800 NE 65TH ST
# 261284           Seating 13-50 - Risk Category III           1314 DENNY WAY
#
#               City Zip Code           Phone  Longitude  Latitude  \
# 20           LACEY    98503  (253) 227-4542        NaN       NaN
# 175         RENTON    98057  (425) 545-5552        NaN       NaN
# 182        SEATTLE    98122  (206) 861-9399    -122.32     47.62
# 603         BURIEN    98168  (206) 838-6020    -122.33     47.47
# 674         Renton    98056  (425) 255-4259    -122.19     47.53
# ...            ...      ...             ...        ...       ...
# 258958     TUKWILA    98168  (425) 728-0706    -122.29     47.51
# 258980     Seattle    98105  (206) 257-0168        NaN       NaN
# 259929  DES MOINES    98198  (425) 239-1571    -122.30     47.40
# 260668     Seattle    98115  (206) 293-9502    -122.32     47.68
# 261284     Seattle    98109  (206) 724-6247        NaN       NaN
#
#        Inspection Business Name Inspection Type  Inspection Score  \
# 20                          NaN             NaN               NaN
# 175                         NaN             NaN               NaN
# 182                         NaN             NaN               NaN
# 603                         NaN             NaN               NaN
# 674                         NaN             NaN               NaN
# ...                         ...             ...               ...
# 258958                      NaN             NaN               NaN
# 258980                      NaN             NaN               NaN
# 259929                      NaN             NaN               NaN
# 260668                      NaN             NaN               NaN
# 261284                      NaN             NaN               NaN
#
#        Inspection Result Inspection Closed Business Violation Type  \
# 20                   NaN                        NaN            NaN
# 175                  NaN                        NaN            NaN
# 182                  NaN                        NaN            NaN
# 603                  NaN                        NaN            NaN
# 674                  NaN                        NaN            NaN
# ...                  ...                        ...            ...
# 258958               NaN                        NaN            NaN
# 258980               NaN                        NaN            NaN
# 259929               NaN                        NaN            NaN
# 260668               NaN                        NaN            NaN
# 261284               NaN                        NaN            NaN
#
#        Violation Description  Violation Points Business_ID  \
# 20                       NaN                 0   PR0091532
# 175                      NaN                 0   PR0091263
# 182                      NaN                 0   PR0081260
# 603                      NaN                 0   PR0076274
# 674                      NaN                 0   PR0013001
# ...                      ...               ...         ...
# 258958                   NaN                 0   PR0090441
# 258980                   NaN                 0   PR0091289
# 259929                   NaN                 0   PR0033573
# 260668                   NaN                 0   PR0045410
# 261284                   NaN                 0   PR0091168
#
#        Inspection_Serial_Num Violation_Record_ID  Grade
# 20                       NaN                 NaN    NaN
# 175                      NaN                 NaN    NaN
# 182                      NaN                 NaN    NaN
# 603                      NaN                 NaN    NaN
# 674                      NaN                 NaN    NaN
# ...                      ...                 ...    ...
# 258958                   NaN                 NaN    NaN
# 258980                   NaN                 NaN    NaN
# 259929                   NaN                 NaN    NaN
# 260668                   NaN                 NaN    NaN
# 261284                   NaN                 NaN    NaN
#
# [462 rows x 22 columns]

# %%
source = (source.dropna(subset = ['Inspection Score'])
         .reset_index(drop=True))
source
# Out:
#                                          Name  \
# 0                            #807 TUTTA BELLA
# 1                            #807 TUTTA BELLA
# 2                            #807 TUTTA BELLA
# 3                            #807 TUTTA BELLA
# 4                            #807 TUTTA BELLA
# ...                                       ...
# 261177  ZYLBERSCHTEIN'S DELICATESSEN & BAKERY
# 261178                             ZZ DESSERT
# 261179                             ZZ DESSERT
# 261180                             ZZ DESSERT
# 261181                             ZZ DESSERT
#
#                            Program Identifier Inspection Date  \
# 0                            #807 TUTTA BELLA      03/02/2023
# 1                            #807 TUTTA BELLA      03/02/2023
# 2                            #807 TUTTA BELLA      08/31/2022
# 3                            #807 TUTTA BELLA      08/31/2022
# 4                            #807 TUTTA BELLA      01/13/2022
# ...                                       ...             ...
# 261177  ZYLBERSCHTEIN'S DELICATESSEN & BAKERY      09/06/2017
# 261178                             ZZ DESSERT      09/26/2023
# 261179                             ZZ DESSERT      01/23/2023
# 261180                             ZZ DESSERT      01/23/2023
# 261181                             ZZ DESSERT      07/28/2022
#
#                              Description                     Address     City  \
# 0       Seating 0-12 - Risk Category III             2746 NE 45TH ST  SEATTLE
# 1       Seating 0-12 - Risk Category III             2746 NE 45TH ST  SEATTLE
# 2       Seating 0-12 - Risk Category III             2746 NE 45TH ST  SEATTLE
# 3       Seating 0-12 - Risk Category III             2746 NE 45TH ST  SEATTLE
# 4       Seating 0-12 - Risk Category III             2746 NE 45TH ST  SEATTLE
# ...                                  ...                         ...      ...
# 261177  Seating 0-12 - Risk Category III           11752 15TH AVE NE  SEATTLE
# 261178  Seating 0-12 - Risk Category III  18230 E VALLEY HWY STE 178     KENT
# 261179  Seating 0-12 - Risk Category III  18230 E VALLEY HWY STE 178     KENT
# 261180  Seating 0-12 - Risk Category III  18230 E VALLEY HWY STE 178     KENT
# 261181  Seating 0-12 - Risk Category III  18230 E VALLEY HWY STE 178     KENT
#
#        Zip Code           Phone  Longitude  Latitude  \
# 0         98105  (206) 722-6400    -122.30     47.66
# 1         98105  (206) 722-6400    -122.30     47.66
# 2         98105  (206) 722-6400    -122.30     47.66
# 3         98105  (206) 722-6400    -122.30     47.66
# 4         98105  (206) 722-6400    -122.30     47.66
# ...         ...             ...        ...       ...
# 261177    98125  (415) 385-1379    -122.31     47.72
# 261178    98032  (206) 779-0528    -122.22     47.44
# 261179    98032  (206) 779-0528    -122.22     47.44
# 261180    98032  (206) 779-0528    -122.22     47.44
# 261181    98032  (206) 779-0528    -122.22     47.44
#
#                      Inspection Business Name  \
# 0                            #807 TUTTA BELLA
# 1                            #807 TUTTA BELLA
# 2                            #807 TUTTA BELLA
# 3                            #807 TUTTA BELLA
# 4                            #807 TUTTA BELLA
# ...                                       ...
# 261177  ZYLBERSCHTEIN'S DELICATESSEN & BAKERY
# 261178                             ZZ DESSERT
# 261179                             ZZ DESSERT
# 261180                             ZZ DESSERT
# 261181                             ZZ DESSERT
#
#                         Inspection Type  Inspection Score Inspection Result  \
# 0       Routine Inspection/Field Review             20.00    Unsatisfactory
# 1       Routine Inspection/Field Review             20.00    Unsatisfactory
# 2       Routine Inspection/Field Review             10.00    Unsatisfactory
# 3       Routine Inspection/Field Review             10.00    Unsatisfactory
# 4       Routine Inspection/Field Review              0.00      Satisfactory
# ...                                 ...               ...               ...
# 261177   Consultation/Education - Field              0.00          Complete
# 261178  Routine Inspection/Field Review              5.00      Satisfactory
# 261179  Routine Inspection/Field Review             10.00      Satisfactory
# 261180  Routine Inspection/Field Review             10.00      Satisfactory
# 261181  Routine Inspection/Field Review              5.00    Unsatisfactory
#
#        Inspection Closed Business Violation Type  \
# 0                           False            RED
# 1                           False            RED
# 2                           False           BLUE
# 3                           False            RED
# 4                           False            NaN
# ...                           ...            ...
# 261177                      False            NaN
# 261178                      False           BLUE
# 261179                      False           BLUE
# 261180                      False           BLUE
# 261181                      False            RED
#
#                                     Violation Description  Violation Points  \
# 0       1300 - Food contact surfaces cleaned and sanit...                15
# 1       2120 - Proper cold holding temperatures ( 42 d...                 5
# 2       3200 - Insects, rodents, animals not present; ...                 5
# 3       0200 - Food Worker Cards current for all food ...                 5
# 4                                                     NaN                 0
# ...                                                   ...               ...
# 261177                                                NaN                 0
# 261178  3400 - Wiping cloths properly used, stored, sa...                 5
# 261179      4400 - Plumbing properly sized, installed,...                 5
# 261180  3400 - Wiping cloths properly used, stored, sa...                 5
# 261181  2120 - Proper cold holding temperatures ( 42 d...                 5
#
#        Business_ID Inspection_Serial_Num Violation_Record_ID  Grade
# 0        PR0089260             DAJ5DTHLV           IVBTPZO0B   1.00
# 1        PR0089260             DAJ5DTHLV           IV5GOME67   1.00
# 2        PR0089260             DAEEWQC0L           IVQ7QYW2V   1.00
# 3        PR0089260             DAEEWQC0L           IV0J437H6   1.00
# 4        PR0089260             DAWWGK08K                 NaN   1.00
# ...            ...                   ...                 ...    ...
# 261177   PR0086991             DALIX7JOT                 NaN   2.00
# 261178   PR0089412             DARMOYIGD           IVD3G9MHG   1.00
# 261179   PR0089412             DAQZ5Q076           IV3MMPWH7   1.00
# 261180   PR0089412             DAQZ5Q076           IVGU0QCRM   1.00
# 261181   PR0089412             DA90U0ZXD           IVFUOGTQ3   1.00
#
# [261182 rows x 22 columns]

# %%
source.isna().sum()
# Out:
# Name                               0
# Program Identifier                 0
# Inspection Date                    0
# Description                        0
# Address                            0
# City                               0
# Zip Code                           0
# Phone                          71406
# Longitude                        811
# Latitude                         811
# Inspection Business Name           0
# Inspection Type                    0
# Inspection Score                   0
# Inspection Result                  0
# Inspection Closed Business         0
# Violation Type                114816
# Violation Description         114816
# Violation Points                   0
# Business_ID                        0
# Inspection_Serial_Num              0
# Violation_Record_ID           114816
# Grade                          63413
# dtype: int64

# %% [markdown]
# ## Possible Target: `Inspection Score`

# %%
source['Inspection Score'].value_counts(dropna=False).sort_index(ascending = False)
# Out:
# Inspection Score
# 180.00        18
# 178.00        14
# 167.00        19
# 154.00        16
# 153.00        34
#            ...
# 2.00        1020
# 0.00      114418
# -1.00          2
# -2.00          2
# -10.00         1
# Name: count, Length: 143, dtype: int64

# %%
source['Inspection Result'].value_counts(dropna=False, normalize = True, ascending = False)
# Out:
# Inspection Result
# Unsatisfactory             0.45
# Satisfactory               0.40
# Complete                   0.14
# Incomplete                 0.00
# Not Accessible             0.00
# Not Applicable             0.00
# Not Ready For Inspection   0.00
# Baseline Data              0.00
# Not Confirmed              0.00
# No Longer At Location      0.00
# Confirmed                  0.00
# In Compliance              0.00
# Out of Business            0.00
# Needs Assessment           0.00
# Not In Compliance          0.00
# Increased Knowledge        0.00
# Not Tested                 0.00
# Not Permitted              0.00
# Name: proportion, dtype: float64

# %%
target_classes = ['Unsatisfactory', 'Satisfactory', 'Complete']

source[source['Inspection Result'].isin(target_classes)]
# Out:
#                                          Name  \
# 0                            #807 TUTTA BELLA
# 1                            #807 TUTTA BELLA
# 2                            #807 TUTTA BELLA
# 3                            #807 TUTTA BELLA
# 4                            #807 TUTTA BELLA
# ...                                       ...
# 261177  ZYLBERSCHTEIN'S DELICATESSEN & BAKERY
# 261178                             ZZ DESSERT
# 261179                             ZZ DESSERT
# 261180                             ZZ DESSERT
# 261181                             ZZ DESSERT
#
#                            Program Identifier Inspection Date  \
# 0                            #807 TUTTA BELLA      03/02/2023
# 1                            #807 TUTTA BELLA      03/02/2023
# 2                            #807 TUTTA BELLA      08/31/2022
# 3                            #807 TUTTA BELLA      08/31/2022
# 4                            #807 TUTTA BELLA      01/13/2022
# ...                                       ...             ...
# 261177  ZYLBERSCHTEIN'S DELICATESSEN & BAKERY      09/06/2017
# 261178                             ZZ DESSERT      09/26/2023
# 261179                             ZZ DESSERT      01/23/2023
# 261180                             ZZ DESSERT      01/23/2023
# 261181                             ZZ DESSERT      07/28/2022
#
#                              Description                     Address     City  \
# 0       Seating 0-12 - Risk Category III             2746 NE 45TH ST  SEATTLE
# 1       Seating 0-12 - Risk Category III             2746 NE 45TH ST  SEATTLE
# 2       Seating 0-12 - Risk Category III             2746 NE 45TH ST  SEATTLE
# 3       Seating 0-12 - Risk Category III             2746 NE 45TH ST  SEATTLE
# 4       Seating 0-12 - Risk Category III             2746 NE 45TH ST  SEATTLE
# ...                                  ...                         ...      ...
# 261177  Seating 0-12 - Risk Category III           11752 15TH AVE NE  SEATTLE
# 261178  Seating 0-12 - Risk Category III  18230 E VALLEY HWY STE 178     KENT
# 261179  Seating 0-12 - Risk Category III  18230 E VALLEY HWY STE 178     KENT
# 261180  Seating 0-12 - Risk Category III  18230 E VALLEY HWY STE 178     KENT
# 261181  Seating 0-12 - Risk Category III  18230 E VALLEY HWY STE 178     KENT
#
#        Zip Code           Phone  Longitude  Latitude  \
# 0         98105  (206) 722-6400    -122.30     47.66
# 1         98105  (206) 722-6400    -122.30     47.66
# 2         98105  (206) 722-6400    -122.30     47.66
# 3         98105  (206) 722-6400    -122.30     47.66
# 4         98105  (206) 722-6400    -122.30     47.66
# ...         ...             ...        ...       ...
# 261177    98125  (415) 385-1379    -122.31     47.72
# 261178    98032  (206) 779-0528    -122.22     47.44
# 261179    98032  (206) 779-0528    -122.22     47.44
# 261180    98032  (206) 779-0528    -122.22     47.44
# 261181    98032  (206) 779-0528    -122.22     47.44
#
#                      Inspection Business Name  \
# 0                            #807 TUTTA BELLA
# 1                            #807 TUTTA BELLA
# 2                            #807 TUTTA BELLA
# 3                            #807 TUTTA BELLA
# 4                            #807 TUTTA BELLA
# ...                                       ...
# 261177  ZYLBERSCHTEIN'S DELICATESSEN & BAKERY
# 261178                             ZZ DESSERT
# 261179                             ZZ DESSERT
# 261180                             ZZ DESSERT
# 261181                             ZZ DESSERT
#
#                         Inspection Type  Inspection Score Inspection Result  \
# 0       Routine Inspection/Field Review             20.00    Unsatisfactory
# 1       Routine Inspection/Field Review             20.00    Unsatisfactory
# 2       Routine Inspection/Field Review             10.00    Unsatisfactory
# 3       Routine Inspection/Field Review             10.00    Unsatisfactory
# 4       Routine Inspection/Field Review              0.00      Satisfactory
# ...                                 ...               ...               ...
# 261177   Consultation/Education - Field              0.00          Complete
# 261178  Routine Inspection/Field Review              5.00      Satisfactory
# 261179  Routine Inspection/Field Review             10.00      Satisfactory
# 261180  Routine Inspection/Field Review             10.00      Satisfactory
# 261181  Routine Inspection/Field Review              5.00    Unsatisfactory
#
#        Inspection Closed Business Violation Type  \
# 0                           False            RED
# 1                           False            RED
# 2                           False           BLUE
# 3                           False            RED
# 4                           False            NaN
# ...                           ...            ...
# 261177                      False            NaN
# 261178                      False           BLUE
# 261179                      False           BLUE
# 261180                      False           BLUE
# 261181                      False            RED
#
#                                     Violation Description  Violation Points  \
# 0       1300 - Food contact surfaces cleaned and sanit...                15
# 1       2120 - Proper cold holding temperatures ( 42 d...                 5
# 2       3200 - Insects, rodents, animals not present; ...                 5
# 3       0200 - Food Worker Cards current for all food ...                 5
# 4                                                     NaN                 0
# ...                                                   ...               ...
# 261177                                                NaN                 0
# 261178  3400 - Wiping cloths properly used, stored, sa...                 5
# 261179      4400 - Plumbing properly sized, installed,...                 5
# 261180  3400 - Wiping cloths properly used, stored, sa...                 5
# 261181  2120 - Proper cold holding temperatures ( 42 d...                 5
#
#        Business_ID Inspection_Serial_Num Violation_Record_ID  Grade
# 0        PR0089260             DAJ5DTHLV           IVBTPZO0B   1.00
# 1        PR0089260             DAJ5DTHLV           IV5GOME67   1.00
# 2        PR0089260             DAEEWQC0L           IVQ7QYW2V   1.00
# 3        PR0089260             DAEEWQC0L           IV0J437H6   1.00
# 4        PR0089260             DAWWGK08K                 NaN   1.00
# ...            ...                   ...                 ...    ...
# 261177   PR0086991             DALIX7JOT                 NaN   2.00
# 261178   PR0089412             DARMOYIGD           IVD3G9MHG   1.00
# 261179   PR0089412             DAQZ5Q076           IV3MMPWH7   1.00
# 261180   PR0089412             DAQZ5Q076           IVGU0QCRM   1.00
# 261181   PR0089412             DA90U0ZXD           IVFUOGTQ3   1.00
#
# [259924 rows x 22 columns]
